# %%
from random import*

# %%
def choix_joueur():
        joueur= int(input("\nChoisir Pierre = 1 ou Ciseaux= 2 ou Feuille= 3\n"))
        pierre=1
        ciseaux=2
        feuille=3

        if joueur==1: 
            resultat_joueur="Pierre"
        elif joueur==2:
            resultat_joueur="Ciseaux"
        else:
            resultat_joueur="Feuille"
        return resultat_joueur

# %%
def choix_ordinateur():
    x= randint(1,3)
    if x==1:
        resultat_ordinateur="Pierre"
    elif x==2:
        resultat_ordinateur="Ciseaux"
    else:
        resultat_ordinateur="Feuille"
    return resultat_ordinateur

# %%
def commencerlejeux():
    j=0
    i=0
    joueur=choix_joueur()
    ordinateur=choix_ordinateur()
    if (joueur==ordinateur):
        print("Egalite!")
    elif (joueur==1 and ordinateur==2) or (joueur==2 and ordinateur==3) or (joueur==3 and ordinateur==1) :  
        print("Le joueur a gagné")
        j=j+1
    else:
        print("Cet ordinateur a gagné")
        i=i+1    
    print('\nLe choix de joueur  est:',joueur,'\net le choix de cet ordinateur est:',ordinateur,
          '\net la résultat pour le joueur est:',j,'\net pour cet ordinateur est :',i)

# %%
commencerlejeux()
# Out:
# Choisir Pierre = 1 ou Ciseaux= 2 ou Feuille= 3
# 3
# Cet ordinateur a gagné
#
# Le choix de joueur  est: Feuille
# et le choix de cet ordinateur est: Pierre
# et la résultat pour le joueur est: 0
# et pour cet ordinateur est : 1
